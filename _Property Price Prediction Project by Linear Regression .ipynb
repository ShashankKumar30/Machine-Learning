# %%
# In first  Importing  some library
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the data file

# %%
df=pd.read_csv(r'C:\Users\admin\Desktop\imarticus\HousePrices.csv')

# %% [markdown]
# After importing the data File and know about the top 5 row of data

# %%
df.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# ...

# %% [markdown]
# To know about the bottom five row

# %%
df.tail()
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# 2068            IR1         Lvl    AllPub  ...        0    NaN  GdPrv
# 2069            IR1         Lvl    AllPub  ...        0    NaN    NaN
# 2070            Reg         Low    AllPub  ...        0    NaN    NaN
# 2071            IR1         Lvl    NoSeWa  ...        0    NaN    NaN
# 2072            Reg         Lvl    AllPub  ...        0    NaN   MnWw
#
#      MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# ...

# %% [markdown]
# It tell the number of rows and columns present in the data

# %%
df.shape
# Out:
# (2073, 81)

# %% [markdown]
# It tell about the whole information about the data like telling about the null value and its type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %% [markdown]
# A summary consists of five values: the most extreme values in the data set (the maximum and minimum values), the lower and upper quartiles, and the median.
# These values are presented together and ordered from lowest to highest: minimum value, lower quartile (Q1), median value (Q2), upper quartile (Q3), maximum value

# %%
df.describe().T
# Out:
#                       count           mean           std      min       25%  \
# Id                   2073.0     916.132176    493.014670      1.0     519.0
# Dwell_Type           2073.0      60.556199    159.924810     20.0      20.0
# LotFrontage          1753.0      72.056475     27.987475     21.0      60.0
# LotArea              2073.0   10717.853353   9215.982306   1300.0    7620.0
# OverallQual          2073.0       6.233478      1.517115      1.0       5.0
# OverallCond          2073.0       5.835022      1.360214      1.0       5.0
# YearBuilt            2073.0    1969.445731     30.222647   1872.0    1950.0
# YearRemodAdd         2073.0    1986.617463     20.432694   1950.0    1970.0
# MasVnrArea           2059.0     101.875668    179.169217      0.0       0.0
# BsmtFinSF1           2073.0     437.949349    448.051119      0.0       0.0
# BsmtFinSF2           2073.0      49.219489    165.621465      0.0       0.0
# ...

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                       False   True
# Id                   2073.0    NaN
# Dwell_Type           2073.0    NaN
# Zone_Class           2073.0    NaN
# LotFrontage          1753.0  320.0
# LotArea              2073.0    NaN
# ...                     ...    ...
# MoSold               2073.0    NaN
# YrSold               2073.0    NaN
# SaleType             2073.0    NaN
# SaleCondition        2073.0    NaN
# Property_Sale_Price  2073.0    NaN
#
# [81 rows x 2 columns]

# %% [markdown]
# # Start of Visualization

# %% [markdown]
# ### Import some more library for Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Showing the missing values

# %%
plt.figure(figsize=(15,5))
missing= df.isnull().sum()
missing= missing[missing > 0]
missing.sort_values(ascending= False, inplace=True)
plt.xlabel("Features", fontsize=15)
plt.ylabel("Number of missing values", fontsize=15)
plt.title("Number of missing data by feature", fontsize=15)
missing.plot(kind="bar")

plt.show()

# %% [markdown]
# Setting options to display all rows and columns

# %%
pd.set_option('max_rows',None)
pd.options.display.max_columns=None

# %%
df.isnull().apply(pd.value_counts).T
# Out:
#                       False    True
# Id                   2073.0     NaN
# Dwell_Type           2073.0     NaN
# Zone_Class           2073.0     NaN
# LotFrontage          1753.0   320.0
# LotArea              2073.0     NaN
# Road_Type            2073.0     NaN
# Alley                 129.0  1944.0
# Property_Shape       2073.0     NaN
# LandContour          2073.0     NaN
# Utilities            2073.0     NaN
# LotConfig            2073.0     NaN
# LandSlope            2073.0     NaN
# Neighborhood         2073.0     NaN
# Condition1           2073.0     NaN
# Condition2           2073.0     NaN
# Dwelling_Type        2073.0     NaN
# HouseStyle           2073.0     NaN
# OverallQual          2073.0     NaN
# OverallCond          2073.0     NaN
# YearBuilt            2073.0     NaN
# YearRemodAdd         2073.0     NaN
# RoofStyle            2073.0     NaN
# RoofMatl             2073.0     NaN
# Exterior1st          2073.0     NaN
# Exterior2nd          2073.0     NaN
# ...

# %% [markdown]
# Droping feature whic has more than 60% values are empty.

# %%
df.drop(['Alley','PoolQC','Fence','MiscFeature','FireplaceQu'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 76 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Property_Shape       2073 non-null   object
#  7   LandContour          2073 non-null   object
#  8   Utilities            2073 non-null   object
#  9   LotConfig            2073 non-null   object
#  10  LandSlope            2073 non-null   object
#  11  Neighborhood         2073 non-null   object
#  12  Condition1           2073 non-null   object
#  13  Condition2           2073 non-null   object
#  14  Dwelling_Type        2073 non-null   object
# ...

# %% [markdown]
# ### Treat Missing Values

# %% [markdown]
# Fill the missing values by their median values of that feature

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median(),inplace=True)
df['GarageYrBlt'].fillna(df['GarageYrBlt'].median(),inplace=True)
df['MasVnrArea'].fillna(df['MasVnrArea'].median(),inplace=True)

# %%
df.isnull().apply(pd.value_counts).T
# Out:
#                       False   True
# Id                   2073.0    NaN
# Dwell_Type           2073.0    NaN
# Zone_Class           2073.0    NaN
# LotFrontage          2073.0    NaN
# LotArea              2073.0    NaN
# Road_Type            2073.0    NaN
# Property_Shape       2073.0    NaN
# LandContour          2073.0    NaN
# Utilities            2073.0    NaN
# LotConfig            2073.0    NaN
# LandSlope            2073.0    NaN
# Neighborhood         2073.0    NaN
# Condition1           2073.0    NaN
# Condition2           2073.0    NaN
# Dwelling_Type        2073.0    NaN
# HouseStyle           2073.0    NaN
# OverallQual          2073.0    NaN
# OverallCond          2073.0    NaN
# YearBuilt            2073.0    NaN
# YearRemodAdd         2073.0    NaN
# RoofStyle            2073.0    NaN
# RoofMatl             2073.0    NaN
# Exterior1st          2073.0    NaN
# Exterior2nd          2073.0    NaN
# MasVnrType           2059.0   14.0
# MasVnrArea           2073.0    NaN
# ...

# %% [markdown]
# Importing the label Encoder library

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Object assigned

# %%
le=LabelEncoder()

# %% [markdown]
# It convert the datatypes from object to int and and filled the values

# %%
df['Road_Type']=le.fit_transform(df['Road_Type'])
df['LandContour']=le.fit_transform(df['LandContour'])
df['Utilities']=le.fit_transform(df['Utilities'])
df['LotConfig']=le.fit_transform(df['LotConfig'])
df['LandSlope']=le.fit_transform(df['LandSlope'])
df['Neighborhood']=le.fit_transform(df['Neighborhood'])
df['Condition1']=le.fit_transform(df['Condition1'])
df['Condition2']=le.fit_transform(df['Condition2'])
df['Dwelling_Type']=le.fit_transform(df['Dwelling_Type'])
df['HouseStyle']=le.fit_transform(df['HouseStyle'])
df['RoofStyle']=le.fit_transform(df['RoofStyle'])
df['RoofMatl']=le.fit_transform(df['RoofMatl'])
df['Exterior1st']=le.fit_transform(df['Exterior1st'])
df['Exterior2nd']=le.fit_transform(df['Exterior2nd'])
df['MasVnrType']=le.fit_transform(df['MasVnrType'])
df['ExterQual']=le.fit_transform(df['ExterQual'])
df['ExterCond']=le.fit_transform(df['ExterCond'])
df['Foundation']=le.fit_transform(df['Foundation'])
df['BsmtQual']=le.fit_transform(df['BsmtQual'])
df['BsmtCond']=le.fit_transform(df['BsmtCond'])
df['BsmtExposure']=le.fit_transform(df['BsmtExposure'])
df['BsmtFinType1']=le.fit_transform(df['BsmtFinType1'])
df['BsmtFinType2']=le.fit_transform(df['BsmtFinType2'])
df['Heating']=le.fit_transform(df['Heating'])
df['HeatingQC']=le.fit_transform(df['HeatingQC'])
df['CentralAir']=le.fit_transform(df['CentralAir'])
df['Electrical']=le.fit_transform(df['Electrical'])
df['KitchenQual']=le.fit_transform(df['KitchenQual'])
df['Functional']=le.fit_transform(df['Functional'])
df['GarageType']=le.fit_transform(df['GarageType'])
df['GarageQual']=le.fit_transform(df['GarageQual'])
df['GarageCond']=le.fit_transform(df['GarageCond'])
df['PavedDrive']=le.fit_transform(df['PavedDrive'])
df['GarageFinish']=le.fit_transform(df['GarageFinish'])
df['SaleType']=le.fit_transform(df['SaleType'])
df['SaleCondition']=le.fit_transform(df['SaleCondition'])
df['Zone_Class']=le.fit_transform(df['Zone_Class'])

# %% [markdown]
# # Heat map

# %% [markdown]
# Following is the heat map of the corelation of the dependent attributes with the independent attributes which is changes in this data.

# %% [markdown]
# The greatest part shows the highly positive value.

# %%
corr=df.corr()

# %%
corr
# Out:
#                            Id  Dwell_Type  Zone_Class  LotFrontage   LotArea  \
# Id                   1.000000    0.043264    0.008184     0.065089  0.004201
# Dwell_Type           0.043264    1.000000    0.002442    -0.074821 -0.033609
# Zone_Class           0.008184    0.002442    1.000000    -0.066743 -0.038714
# LotFrontage          0.065089   -0.074821   -0.066743     1.000000  0.237671
# LotArea              0.004201   -0.033609   -0.038714     0.237671  1.000000
# Road_Type           -0.009714   -0.005419    0.056364    -0.039385 -0.144528
# LandContour         -0.023591    0.010011   -0.000062    -0.059358 -0.141765
# Utilities            0.002230   -0.009657   -0.001580    -0.011446  0.015111
# LotConfig            0.015822    0.029538   -0.017439    -0.127927 -0.103496
# LandSlope            0.005695    0.068747   -0.017926     0.077017  0.357898
# Neighborhood        -0.004485   -0.020327   -0.242801     0.047215  0.029985
# ...

# %%
plt.figure(figsize=(15,9))
sns.heatmap(corr,vmax=1.0,vmin=-1.0,fmt='g',cmap='RdYlGn',annot=True)
plt.title('Correlation_Matrix',fontsize=20)
plt.show()

# %%
a=corr[['Property_Sale_Price']]

# %% [markdown]
# #### Zoomed Heat Map

# %%
plt.figure(figsize=(15,9))
sns.heatmap(a,vmax=1.0,vmin=-1.0,fmt='g',cmap='RdYlGn',annot=True)
plt.title('Correlation_Matrix',fontsize=20)
plt.show()

# %% [markdown]
# ## Skewness

# %% [markdown]
# Skewness tell us that where the maximumvlaue is . it will show the inclination slides

# %%
sk = df.skew()
sk
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_7648/1087335717.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sk = df.skew()
# Id                     -0.033712
# Dwell_Type             40.872292
# Zone_Class             -1.685556
# LotFrontage             3.781306
# LotArea                11.239413
# Road_Type             -14.303877
# LandContour            -3.080534
# Utilities              26.248779
# LotConfig              -1.093727
# LandSlope               4.628037
# Neighborhood            0.039773
# Condition1              3.285181
# Condition2             14.228737
# Dwelling_Type           2.194492
# HouseStyle              0.297938
# OverallQual             0.196350
# OverallCond             0.649335
# YearBuilt              -0.516261
# YearRemodAdd           -0.579862
# ...

# %%
# Sale Price Frequency Distribution
plt.figure(figsize=(8,6))
plt.xlabel("Sale Price", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.title("Property_Sale_Price", fontsize=15)
plt.hist(df["Property_Sale_Price"], color= "pink")
plt.show()

# %% [markdown]
# # Boxplot

# %% [markdown]
#  Boxplot of HouseStyle and Property_Sale_Price

# %%
plt.figure(figsize=(12,8))
sns.boxplot(y="Property_Sale_Price", x="HouseStyle", data= df)
plt.title("Property_Sale_Price vs HouseStyle", fontsize=15)
plt.xlabel("HouseStyle", fontsize=15)
plt.ylabel("Property_Sale_Price", fontsize=15)
plt.show()

# %% [markdown]
#  Boxplot of OverallQual and Property_Sale_Price

# %%
plt.figure(figsize=(12,8))
sns.boxplot(y="Property_Sale_Price", x="OverallQual", data= df)
plt.title("Property_Sale_Price vs HouseStyle", fontsize=15)
plt.xlabel("OverallQual", fontsize=15)
plt.ylabel("Property_Sale_Price", fontsize=15)
plt.show()

# %% [markdown]
# Drop Feature

# %%
df.drop(['Id','Dwell_Type','Zone_Class','Property_Shape','Utilities','LotConfig','Dwelling_Type'
         ,'OverallCond','ExterQual','BsmtQual','BsmtCond','BsmtExposure',
'BsmtFinType1','BsmtFinSF2','Heating','HeatingQC','LowQualFinSF','BsmtHalfBath'
         ,'KitchenAbvGr','KitchenQual','GarageType','GarageFinish','EnclosedPorch','MiscVal','SaleType'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'Road_Type', 'LandContour', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'HouseStyle', 'OverallQual',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterCond', 'Foundation',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtUnfSF', 'TotalBsmtSF', 'CentralAir',
#        'Electrical', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'TotRmsAbvGrd', 'Functional',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MoSold', 'YrSold', 'SaleCondition',
#        'Property_Sale_Price'],
#       dtype='object')

# %%
# Taking  Independent Variable
X=df[['LotFrontage', 'LotArea', 'Road_Type', 'LandContour', 'LandSlope',
       'Neighborhood', 'Condition1', 'Condition2', 'HouseStyle', 'OverallQual',
       'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterCond', 'Foundation',
       'BsmtFinSF1', 'BsmtFinType2', 'BsmtUnfSF', 'TotalBsmtSF', 'CentralAir',
       'Electrical', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
       'FullBath', 'HalfBath', 'BedroomAbvGr', 'TotRmsAbvGrd', 'Functional',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MoSold', 'YrSold', 'SaleCondition']]

# %%
X.head()
# Out:
#    LotFrontage  LotArea  Road_Type  LandContour  LandSlope  Neighborhood  \
# 0         65.0     8450          1            3          0             5
# 1         80.0     9600          1            3          0            24
# 2         68.0    11250          1            3          0             5
# 3         60.0     9550          1            3          0             6
# 4         84.0    14260          1            3          0            15
#
#    Condition1  Condition2  HouseStyle  OverallQual  YearBuilt  YearRemodAdd  \
# 0           2           2           5            7       2003          2003
# 1           1           2           2            6       1976          1976
# 2           2           2           5            7       2001          2002
# 3           2           2           5            7       1915          1970
# 4           2           2           5            8       2000          2000
#
# ...

# %%
#Dependent Variables
y=df[['Property_Sale_Price']]

# %%
y.head()
# Out:
#    Property_Sale_Price
# 0               208500
# 1               181500
# 2               223500
# 3               140000
# 4               250000

# %%
x=X.values.reshape(-1,1)

# %%
y=y.values.reshape(-1,1)

# %%
#train_test_split
from sklearn.model_selection import train_test_split

# %%
#splitting of data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,train_size=0.7,random_state=1)

# %%
X_train.shape
# Out:
# (1451, 50)

# %%
X_test.shape
# Out:
# (622, 50)

# %%
X.shape
# Out:
# (2073, 50)

# %%
y_train.shape
# Out:
# (1451, 1)

# %%
y_test.shape
# Out:
# (622, 1)

# %%
y.shape
# Out:
# (2073, 1)

# %%
# Importing Linear regression
from sklearn.linear_model import LinearRegression

# %%
#Object creation
model=LinearRegression()

# %%
#training the model using .fit() function
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#testing the data/model or predicting the data or predicting the model (y^)
y_pred=model.predict(X_test)
y_pred
# Out:
# array([[318725.9172769 ],
#        [212132.65567935],
#        [109113.44214498],
#        [150317.0429943 ],
#        [155903.53944552],
#        [184920.39418985],
#        [ 75113.58856509],
#        [190330.168159  ],
#        [227647.37528926],
#        [130933.7215961 ],
#        [168529.28226229],
#        [307544.57680554],
#        [207342.5449892 ],
#        [142352.72629041],
#        [166455.28131379],
#        [186122.55686372],
#        [181319.25886369],
#        [923664.63979335],
#        [210470.57914329],
#        [ 88027.12334308],
#        [ 65061.15139331],
#        [212320.60795365],
#        [151658.14639769],
#        [174241.87633224],
#        [270617.80157274],
#        [ 41628.09651805],
#        [163973.66177526],
#        [267123.05591839],
#        [173416.65660559],
#        [304330.54676341],
#        [189488.08609984],
#        [120020.03236083],
#        [159339.97105563],
#        [238454.36616214],
#        [176150.56302365],
# ...

# %% [markdown]
# Importing of r2 Library

# %%
from sklearn.metrics import r2_score

# %%
#Counting R2 score by
r2_score(y_test,y_pred)*100
# Out:
# 69.66819488500235

# %%
model.score(X_test,y_test)*100
# Out:
# 69.66819488500235

# %%
model.score(X_train,y_train)*100
# Out:
# 82.58670913932049

# %%
#Adjusted R_square
adj_r2_score=1-(1-model.score(X_test,y_test))*len((y_train)-1)/(len(y_train)-y_test.shape[1]-1)
adj_r2_score
# Out:
# 0.69626329039433

# %%
adj_r2_score*100
# Out:
# 69.626329039433

# %% [markdown]
# Importing the library of mean_square_error

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Its range always between -infinite to + infinite we are applying formula to find out mean_square_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1853100858.1691322

# %%
sns.set(style="ticks", color_codes=True)
columns= ['LotFrontage', 'LotArea', 'Road_Type', 'LandContour', 'LandSlope',
       'Neighborhood', 'Condition1', 'Condition2', 'HouseStyle', 'OverallQual',
       'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterCond', 'Foundation',
       'BsmtFinSF1', 'BsmtFinType2', 'BsmtUnfSF', 'TotalBsmtSF', 'CentralAir',
       'Electrical', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
       'FullBath', 'HalfBath', 'BedroomAbvGr', 'TotRmsAbvGrd', 'Functional',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MoSold', 'YrSold', 'SaleCondition',
       'Property_Sale_Price']
sns.pairplot(df[columns], size=2, kind= "scatter", diag_kind="kde")
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
